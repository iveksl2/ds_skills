# %% [markdown]
# <a href="https://colab.research.google.com/github/iveksl2/ds_skills/blob/master/testing_integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from graphviz import Digraph
dot = Digraph(comment='MLOps Flow as a DAG')

# %%
print(dot)
dot.node('D', 'Feature Store')
dot.node('L', 'ML Model Lab')
dot.node('S', 'ML Model Stage')
dot.node('P', 'ML Model Production')
dot.node('M', 'ML Model Monitoring')
# Out:
# // MLOps Flow as a DAG
# digraph {
# }

# %%
dot.edges(['DL', 'DS', 'DP',])
dot.edges(['LM', 'SM', 'PM',])
dot.edge('L', 'S', )#constraint='false')
dot.edge('S', 'P', )# constraint='false')
dot.edges(['PD'])

# %%
print(dot.source) 
dot.render('test-output/round-table.jpg', view=True)
dot
# Out:
# // MLOps Flow as a DAG
# digraph {
# 	D [label="Feature Store"]
# 	L [label="ML Model Lab"]
# 	S [label="ML Model Stage"]
# 	P [label="ML Model Production"]
# 	M [label="ML Model Monitoring"]
# 	D -> L
# 	D -> S
# 	D -> P
# 	L -> M
# 	S -> M
# 	P -> M
# 	L -> S
# 	S -> P
# 	P -> D
# }

# %%
# !ls /gdrive/'My Drive' -lax'
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
# !ls
# Out:
# sample_data  test-output
