# %% [markdown]
# <a href="https://colab.research.google.com/github/iveksl2/ds_skills/blob/master/visualize/Copy_of_Heatmaps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np; np.random.seed(0)
import pandas as pd
import seaborn as sns; sns.set_theme()

# %%
# Seaborn Tutorial
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %%
ax = sns.heatmap(uniform_data, vmin=0, vmax=1)

# %%
normal_data = np.random.randn(10, 12)
ax = sns.heatmap(normal_data, center=0)

# %% [markdown]
# Plot a dataframe with meanginful row and column labels

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights = flights.pivot("month", "year", "passengers")

# %%
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
ax = sns.heatmap(flights)

# %%
ax = sns.heatmap(flights, annot=True, fmt="d")

# %%
ax = sns.heatmap(flights, linewidths=.5)

# %%
ax = sns.heatmap(flights, cmap="YlGnBu")

# %%
# Defining index for the dataframe
idx = ['1', '2', '3', '4']
  
# Defining columns for the dataframe
cols = list('ABCD')
  
# Entering values in the index and columns  
# and converting them into a panda dataframe
df = pd.DataFrame([[10, 20, 30, 40], [50, 30, 8, 15],
                   [25, 14, 41, 8], [7, 14, 21, 28]],
                   columns = cols, index = idx)
  
# generating pairwise correlation
corr = df.corr()
  
# Displaying dataframe as an heatmap 
# with diverging colourmap as coolwarm
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style  type="text/css" >
# #T_2660d966_903e_11eb_8949_0242ac1c0002row0_col0,#T_2660d966_903e_11eb_8949_0242ac1c0002row1_col1,#T_2660d966_903e_11eb_8949_0242ac1c0002row2_col2,#T_2660d966_903e_11eb_8949_0242ac1c0002row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_2660d966_903e_11eb_8949_0242ac1c0002row0_col1{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_2660d966_903e_11eb_8949_0242ac1c0002row0_col2{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_2660d966_903e_11eb_8949_0242ac1c0002row0_col3,#T_2660d966_903e_11eb_8949_0242ac1c0002row1_col2,#T_2660d966_903e_11eb_8949_0242ac1c0002row2_col1,#T_2660d966_903e_11eb_8949_0242ac1c0002row3_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_2660d966_903e_11eb_8949_0242ac1c0002row1_col0{
#             background-color:  #dd5f4b;
#             color:  #000000;
# ...
